# %% [markdown]
# # Test: Images

# %%
from IPython.display import Image

# %% [markdown]
# ![](https://image.tmdb.org/t/p/w500/wwemzKWzjKYJFfCeiB57q3r4Bcm.png)

# %%
def poster_url(poster_path, width=200):
    url = f"https://image.tmdb.org/t/p/w{width}{poster_path}"
    return url

# %%
Image(poster_url('/ojDg0PGvs6R9xYFodRct2kdI6wC.jpg'))
