# %% [markdown]
# # Test: Metrics for Multi-Label Classification

# %%
import pandas
import numpy

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %% [markdown]
# **common metrics**
#
# - Precision at k
# - Avg precision at k-
# - Mean avg precision at k
# - Sampled F1 Score

# %% [markdown]
# ## Choice: Sampled F1

# %%
from sklearn.metrics import f1_score

# %% [markdown]
# ## Test on Genre Labels

# %%
movies = catalog.load("movies")
# Out:
# 2021-03-11 12:40:39,044 - kedro.io.data_catalog - INFO - Loading data from `movies` (ParquetDataSet)...

# %%
movies["genre_names"] = movies["genres"].apply(lambda ls: [d["name"] for d in ls])

# %%
genre_labels = pandas.get_dummies(
    movies["genre_names"].apply(pandas.Series).stack(),
    prefix="Genre"
).sum(level=0)
# Out:
# /Users/cls/Documents/Freelancing/Projects/WildCodeSchool/env_movie_poster_classifier/lib/python3.8/site-packages/pandas/core/series.py:4138: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   mapped = lib.map_infer(values, f, convert=convert_dtype)

# %% [markdown]
# **F1**

# %% [markdown]
# _test with identity_

# %%
f1_score(genre_labels, genre_labels, average="samples")
# Out:
# 1.0

# %% [markdown]
# _test with zeros_

# %%
f1_score(
    genre_labels, 
    numpy.zeros(genre_labels.shape), 
    average="samples"
)
# Out:
# 0.0

# %% [markdown]
# _test with random labels_

# %%
f1_score(
    genre_labels, 
    numpy.random.randint(2, size=genre_labels.shape), 
    average="samples"
)
# Out:
# 0.1842742919052415
